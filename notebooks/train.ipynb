# %%
# !pip install ultralytics roboflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 30.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.0/285.0 kB 27.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 18.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 88.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 140.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 5.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 5.0.0.93
#     Uninstalling opencv-python-headless-5.0.0.93:
#       Successfully uninstalled opencv-python-headless-5.0.0.93
#   Attempting uninstall: typer
#     Found existing installation: typer 0.26.8
#     Uninstalling typer-0.26.8:
#       Successfully uninstalled typer-0.26.8
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="YOUR_API_KEY")
project = rf.workspace("parul-university-wsshr").project("pothole-detection-using-yolov8")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to pothole-detection-using-yolov8-2 in yolov8:: 100%|██████████| 2492/2492 [00:00<00:00, 5506.84it/s]
# Creating new Ultralytics Settings v0.0.7 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !yolo detect train data=/content/pothole-detection-using-yolov8-2/data.yaml model=yolov8n.pt epochs=50 imgsz=640 batch=16 name=pothole_severity
# Out:
# ...
# Ultralytics 8.4.115 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from ultralytics import YOLO
model = YOLO("/content/runs/detect/pothole_severity/weights/best.pt")
results = model.predict("/content/pothole-detection-using-yolov8-2/valid/images", save=True, conf=0.25)
# Out:
# image 1/248 /content/pothole-detection-using-yolov8-2/valid/images/img-1000_jpg.rf.a0a9965110208e5d1fde2746fcab7e83.jpg: 640x640 4 0s, 7.3ms
# image 2/248 /content/pothole-detection-using-yolov8-2/valid/images/img-1003_jpg.rf.67151e752f6eabcd18a8e4c9b3c20c34.jpg: 640x640 1 0, 7.2ms
# image 3/248 /content/pothole-detection-using-yolov8-2/valid/images/img-1008_jpg.rf.ba3deb1c3daa4581a741a06c6151089b.jpg: 640x640 3 0s, 7.2ms
# image 4/248 /content/pothole-detection-using-yolov8-2/valid/images/img-100_jpg.rf.f452d5225ee666aac050aec509081960.jpg: 640x640 2 0s, 7.2ms
# image 5/248 /content/pothole-detection-using-yolov8-2/valid/images/img-1013_jpg.rf.8b977dd55d0204a99800c74b6c2113cf.jpg: 640x640 1 0, 7.3ms
# image 6/248 /content/pothole-detection-using-yolov8-2/valid/images/img-1014_jpg.rf.7ad8216118fd4081bfb30eeb31b90af5.jpg: 640x640 7 0s, 7.2ms
# image 7/248 /content/pothole-detection-using-yolov8-2/valid/images/img-1024_jpg.rf.06a1a0ea4399d13ebec24707333e93f8.jpg: 640x640 1 0, 7.2ms
# ...

# %%
from google.colab import files
files.download('/content/runs/detect/pothole_severity/weights/best.pt')
